# %%
import holoviews as hv
import panel as pn
pn.extension()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# ...

# %%
files = pn.widgets.FileSelector('~/data')

card = pn.Card(files, title='Initial Config', styles={'background': 'WhiteSmoke'})

card
# Out:
# Card(styles={'background': '...}, title='Initial Config')
#     [0] FileSelector(directory='/Users/brenda/data')

# %%
files.value
# Out:
# []

# %%
#help(pn.widgets.Textbox)

# %%
pn.extension(design="material", sizing_mode="stretch_width")
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# ...

# %%
def transform_data(variable, window, sigma):
    """Calculates the rolling average and identifies outliers"""
    avg = data[variable].rolling(window=window).mean()
    residual = data[variable] - avg
    std = residual.rolling(window=window).std()
    outliers = np.abs(residual) > std * sigma
    return avg, avg[outliers]

# construct list of date/times from 

# variable, elevation, time? or data file? use time?
def get_plot(variable="Temperature", window=30, sigma=10):
    """Plots the rolling average and the outliers"""
    avg, highlight = transform_data(variable, window, sigma)
    return avg.hvplot(
        height=300, legend=False, color=PRIMARY_COLOR
    ) * highlight.hvplot.scatter(color=SECONDARY_COLOR, padding=0.1, legend=False)

def get_data_location(file_dir='~/data'):
    return pn.Card(files, title='Initial Config', styles={'background': 'WhiteSmoke'})

# %%
#bound_card = pn.bind(
#    get_data_location, file_dir=variable_widget, window=window_widget, sigma=sigma_widget
#)

# %%
#widgets = pn.Column(variable_widget, window_widget, sigma_widget, sizing_mode="fixed", width=300)
#pn.Column(widgets, bound_plot)
pn.Column(card)
# Out:
# Column(design=<class 'panel.theme.materi..., sizing_mode='stretch_width')
#     [0] Card(design=<class 'panel.theme.materi..., sizing_mode='stretch_width', styles={'background': '...}, title='Initial Config')
#         [0] FileSelector(design=<class 'panel.theme.materi..., directory='/Users/brenda/data', sizing_mode='stretch_width')

# %%
# make this into a stand alone app
pn.template.MaterialTemplate(
    site="Panel",
    title="Getting Started App",
    #sidebar=[card],
    #main=[bound_plot],
    main=[card],
).servable(); # The ; is needed in the notebook to not display the template. Its not needed in a script

# %%
# at the terminal: 
# mamba activate bokeh_heatmap_env
# (bokeh_heatmap_env) $ panel serve panel_file_chooser.ipynb --autoreload

#panel serve panel_file_chooser.ipynb --autoreload

# Now, open the app in your browser at http://localhost:5006/app.
# Out:
#   Cell In[35], line 1
#     panel serve panel_file_chooser.ipynb --autoreload
#           ^
# SyntaxError: invalid syntax

# %%
#def my_func(value1, value2):
#    return some_python_object

#widget1 = pn.widgets.SomeWidget(value=..., ...).servable(area='sidebar')
#widget2 = pn.widgets.AnotherWidget(value=..., ...).servable(area='sidebar')

#widget3 = pn.widgets.file_selector.FileSelector(directory='~', file_pattern='*.*').servable(area='sidebar')

#    3. Bind the function to your widgets

#interactive_func = pn.bind(my_func, value1=widget1, value2=widget2)

#    4. Layout your interactive function in a panel, Column, Row or similar

#pn.panel(interactive_func).servable()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 pn.widget.file_selector.FileSelector(directory='~', file_pattern='*.*')
#
# AttributeError: type object 'widget' has no attribute 'file_selector'

# %%
#help(pn.widgets)
#help(pn.viewable)

#def transform_data(variable, window, sigma):
#    """Calculates the rolling average and identifies outliers"""
#    avg = data[variable].rolling(window=window).mean()
#    residual = data[variable] - avg
#    std = residual.rolling(window=window).std()
#    outliers = np.abs(residual) > std * sigma
#    return avg, avg[outliers]


#def get_plot(variable="Temperature", window=30, sigma=10):
#    """Plots the rolling average and the outliers"""
#    #avg, highlight = transform_data(variable, window, sigma)
#    avg = [1,3,4,5,6]
#    return avg.hvplot(
#        height=300, legend=False, color=PRIMARY_COLOR
#    ) #  * highlight.hvplot.scatter(color=SECONDARY_COLOR, padding=0.1, legend=False)

# %%
#get_plot(variable='Temperature', window=20, sigma=10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 get_plot(variable='Temperature', window=20, sigma=10)
#
# Cell In[22], line 17, in get_plot(variable, window, sigma)
#      15 #avg, highlight = transform_data(variable, window, sigma)
#      16 avg = [1,3,4,5,6]
# ---> 17 return avg.hvplot(
#      18     height=300, legend=False, color=PRIMARY_COLOR
#      19 )
#
# AttributeError: 'list' object has no attribute 'hvplot'

# %%
#variable_widget = pn.widgets.Select(name="variable", value="Temperature", options=list(data.columns))
#window_widget = pn.widgets.IntSlider(name="window", value=30, start=1, end=60)
#sigma_widget = pn.widgets.IntSlider(name="sigma", value=10, start=0, end=20)

# %%
#bound_plot = pn.bind(
#    get_plot, variable=variable_widget, window=window_widget, sigma=sigma_widget
#)

# %%
#widgets = pn.Column(variable_widget, window_widget, sigma_widget, sizing_mode="fixed", width=300)
#pn.Column(widgets, bound_plot)

# %%
#pn.template.MaterialTemplate(
#    site="Panel",
#    title="Getting Started App",
#    sidebar=[variable_widget, window_widget, sigma_widget],
#    main=[bound_plot],
#).servable(); # The ; is needed in the notebook to not display the template. Its not needed in a script

# %%
# If you prefer developing in a Python Script using an editor, you can copy the code into a file app.py and serve it.

# panel serve app.py --autoreload
