# %%
import holoviews as hv
import panel as pn
pn.extension()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='f4f8d7cd-4c71-411c-b19f-eb3da8d2139a'>
#   <div id="b4e30136-12d6-4a13-b77f-9a6deb8d14c7" data-root-id="f4f8d7cd-4c71-411c-b19f-eb3da8d2139a" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"bd2f59bd-e5e4-472e-a4fc-7ec38153f433":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"f4f8d7cd-4c71-411c-b19f-eb3da8d2139a"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"09068f9a-eb69-464a-bafc-754fb210a3c9","attributes":{"plot_id":"f4f8d7cd-4c71-411c-b19f-eb3da8d2139a","comm_id":"589648c87ecf4c68b29c7038a884a608","client_comm_id":"bfff680129e4414e9119bca7303cc3e1"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"bd2f59bd-e5e4-472e-a4fc-7ec38153f433","roots":{"f4f8d7cd-4c71-411c-b19f-eb3da8d2139a":"b4e30136-12d6-4a13-b77f-9a6deb8d14c7"},"root_ids":["f4f8d7cd-4c71-411c-b19f-eb3da8d2139a"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
file_selector_widget = pn.widgets.FileSelector('~/data')

card = pn.Card(file_selector_widget, title='Step 1. Choose Data File', styles={'background': 'WhiteSmoke'})

# %%
file_selector_widget
# Out:
# FileSelector(directory='/Users/brenda/data')

# %%
pn.extension(design="material", sizing_mode="stretch_width")
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='083930ad-e53e-4e95-9772-9e49f5b20c51'>
#   <div id="c9245d17-525f-4630-931e-e6b3332783fd" data-root-id="083930ad-e53e-4e95-9772-9e49f5b20c51" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"1161f833-bc38-4f5e-8a69-fc00e1c5807b":{"version":"3.4.1","title":"Bokeh Application","roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"083930ad-e53e-4e95-9772-9e49f5b20c51"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"0eec3264-b983-4254-8ac4-0945441ec07c","attributes":{"plot_id":"083930ad-e53e-4e95-9772-9e49f5b20c51","comm_id":"c4d2710649504d37b804b260f9eca3e1","client_comm_id":"97b4df779cf648adaf4bdfe6500ed8db"}}],"defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"gap","kind":"Any","default":""},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"js_events","kind":"Any","default":{"type":"map"}},{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"TemplateEditor1","properties":[{"name":"layout","kind":"Any","default":[]}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","def ...
#   var render_items = [{"docid":"1161f833-bc38-4f5e-8a69-fc00e1c5807b","roots":{"083930ad-e53e-4e95-9772-9e49f5b20c51":"c9245d17-525f-4630-931e-e6b3332783fd"},"root_ids":["083930ad-e53e-4e95-9772-9e49f5b20c51"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.').replace('.dev', '-dev.')
#   async function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     await Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && id_el.children[0].hasAttribute('data-root-id')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	  for (const child of root_el.children) {
#             // Ensure JupyterLab does not capture keyboard shortcuts
#             // see: https://jupyterlab.readthedocs.io/en/4.1.x/extension/notebook.html#keyboard-interaction-model
# 	    child.setAttribute('data-lm-suppress-shortcuts', 'true')
# 	  }
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
# file_selector_widget.value

# %%
#bound_card = pn.bind(
#    get_data_location, file_dir=variable_widget, window=window_widget, sigma=sigma_widget
#)

# %%
#widgets = pn.Column(variable_widget, window_widget, sigma_widget, sizing_mode="fixed", width=300)
#pn.Column(widgets, bound_plot)
pn.Column(card)
# Out:
# Column(design=<class 'panel.theme.materi..., sizing_mode='stretch_width')
#     [0] Card(styles={'background': '...}, title='Step 1. Choose D...)
#         [0] FileSelector(directory='/Users/brenda/data')

# %%
import numpy as np
import pandas as pd
import panel as pn
import hvplot.pandas
import xarray as xr
import xradar as xd
import cmweather
import matplotlib.pyplot as plt
import pyproj
#import cartopy
import hvplot.xarray

# %%
localfilename = file_selector_widget.value
display(localfilename[0])
type(localfilename[0])
type("one")
# Out:
# '/Users/brenda/data/cfrad.20161006_190650.891_to_20161006_191339.679_KAMX_SUR.nc'
# str

# %%
#help(xd.io)

# %%
# Use this after binding file chooser to open file
# ds = xr.open_dataset(localfilename[0])
#ds = xd.io.open_cfradial1_datatree("/Users/brenda/data/cfrad.20170408_001452.962_to_20170408_002320.954_KARX_Surveillance_SUR.nc",
#                                  first_dim="auto")
  # PRECIP/SEA20220702_001310_ppi.nc") # , group="sweep_0") # , engine="nexradlevel2")
# ds = xd.io.open_cfradial1_datatree("/Users/brenda/data/cfrad.20161006_190650.891_to_20161006_191339.679_KAMX_SUR.nc")
#                                  group="sweep_0", engine="nexradlevel2" )
#ds = xd.io.open_dataset("/Users/brenda/data/cfrad.20170408_001452.962_to_20170408_002320.954_KARX_SUR.nc")

#ds = xr.open_dataset(filename, group="sweep_0", engine="nexradlevel2")

# help(xd.open_datatree)
# NEXRAD
path = "/Users/brenda/data/for_mica/nexrad/"
filename = "KBBX20240510_010615_V06"
datatree = xd.io.backends.nexrad_level2.open_nexradlevel2_datatree(path+filename)
display(datatree)

# there is an error in xradar datatree, it wants n_points, which it doesn't find.
# ncdump of the file has n_points, but just reading cfradial1 using datatree,
# there is no n_points.
#path = "/Users/brenda/data/for_mica/nexrad/output/20240510/"
#filename = "cfrad.20240510_010615.273_to_20240510_011309.471_KBBX_SUR.nc"
#ds = xd.io.backends.cfradial1.open_cfradial1_datatree(path+filename, sweep=0)
#display(ds)
# Out:
# DataTree('root', parent=None)
# │   Dimensions:              ()
# │   Data variables:
# │       volume_number        int64 8B 0
# │       platform_type        <U5 20B 'fixed'
# │       instrument_type      <U5 20B 'radar'
# │       time_coverage_start  <U20 80B '2024-05-11T01:06:15Z'
# │       time_coverage_end    <U20 80B '2024-05-11T01:13:09Z'
# │       longitude            float64 8B -121.6
# │       altitude             int64 8B 67
# │       latitude             float64 8B 39.5
# │   Attributes:
# │       Conventions:      None
# │       instrument_name:  KBBX
# │       version:          None
# │       title:            None
# │       institution:      None
# │       references:       None
# │       source:           None
# │       history:          None
# │       comment:          im/exported using xradar
# ├── DataTree('sweep_0')
# │       Dimensions:            (azimuth: 720, range: 1832)
# │       Coordinates:
# │           elevation          (azimuth) float64 6kB ...
# │           time               (azimuth) datetime64[ns] 6kB 2024-05-11T01:07:06.96499...
# │         * range              (range) float32 7kB 2.125e+03 2.375e+03 ... 4.599e+05
# │           longitude          float64 8B ...
# │           latitude           float64 8B ...
# │           altitude           int64 8B ...
# │         * azimuth            (azimuth) float64 6kB 0.2499 0.7581 1.25 ... 359.3 359.7
# │       Data variables:
# │           DBZH               (azimuth, range) float64 11MB ...
# │           ZDR                (azimuth, range) float64 11MB ...
# │           PHIDP              (azimuth, range) float64 11MB ...
# │           RHOHV              (azimuth, range) float64 11MB ...
# │           CCORH              (azimuth, range) float64 11MB ...
# │           sweep_mode         <U20 80B ...
# │           sweep_number       int64 8B ...
# │           prt_mode           <U7 28B ...
# │           follow_mode        <U7 28B ...
# │           sweep_fixed_angle  float64 8B ...
# │       Attributes:
# │           instrument_name:  KBBX
# ├── DataTree('sweep_1')
# │       Dimensions:            (azimuth: 720, range: 1192)
# │       Coordinates:
# │           elevation          (azimuth) float64 6kB ...
# │           time               (azimuth) datetime64[ns] 6kB 2024-05-11T01:07:44.98499...
# │         * range              (range) float32 5kB 2.125e+03 2.375e+03 ... 2.999e+05
# │           longitude          float64 8B ...
# │           latitude           float64 8B ...
# │           altitude           int64 8B ...
# │         * azimuth            (azimuth) float64 6kB 0.2142 0.7224 1.214 ... 359.2 359.7
# │       Data variables:
# │           DBZH               (azimuth, range) float64 7MB ...
# │           VRADH              (azimuth, range) float64 7MB ...
# │           WRADH              (azimuth, range) float64 7MB ...
# │           sweep_mode         <U20 80B ...
# │           sweep_number       int64 8B ...
# │           prt_mode           <U7 28B ...
# │           follow_mode        <U7 28B ...
# │           sweep_fixed_angle  float64 8B ...
# │       Attributes:
# │           instrument_name:  KBBX
# ├── DataTree('sweep_2')
# │       Dimensions:            (azimuth: 720, range: 1832)
# │       Coordinates:
# │           elevation          (azimuth) float64 6kB ...
# │           time               (azimuth) datetime64[ns] 6kB 2024-05-11T01:08:40.53600...
# │         * range              (range) float32 7kB 2.125e+03 2.375e+03 ... 4.599e+05
# │           longitude          float64 8B ...
# │           latitude           float64 8B ...
# │           altitude           int64 8B ...
# │         * azimuth            (azimuth) float64 6kB 0.2499 0.7498 1.25 ... 359.3 359.7
# │       Data variables:
# │           DBZH               (azimuth, range) float64 11MB ...
# │           ZDR                (azimuth, range) float64 11MB ...
# │           PHIDP              (azimuth, range) float64 11MB ...
# │           RHOHV              (azimuth, range) float64 11MB ...
# │           CCORH              (azimuth, range) float64 11MB ...
# │           sweep_mode         <U20 80B ...
# │           sweep_number       int64 8B ...
# │           prt_mode           <U7 28B ...
# │           follow_mode        <U7 28B ...
# │           sweep_fixed_angle  float64 8B ...
# │       Attributes:
# │           instrument_name:  KBBX
# ├── DataTree('sweep_3')
# │       Dimensions:            (azimuth: 720, range: 1192)
# │       Coordinates:
# │           elevation          (azimuth) float64 6kB ...
# │           time               (azimuth) datetime64[ns] 6kB 2024-05-11T01:09:21.98800...
# │         * range              (range) float32 5kB 2.125e+03 2.375e+03 ... 2.999e+05
# │           longitude          float64 8B ...
# │           latitude           float64 8B ...
# │           altitude           int64 8B ...
# │         * azimuth            (azimuth) float64 6kB 0.217 0.7196 1.219 ... 359.2 359.7
# │       Data variables:
# │           DBZH               (azimuth, range) float64 7MB ...
# │           VRADH              (azimuth, range) float64 7MB ...
# │           WRADH              (azimuth, range) float64 7MB ...
# │           sweep_mode         <U20 80B ...
# │           sweep_number       int64 8B ...
# │           prt_mode           <U7 28B ...
# │           follow_mode        <U7 28B ...
# │           sweep_fixed_angle  float64 8B ...
# │       Attributes:
# │           instrument_name:  KBBX
# ├── DataTree('sweep_4')
# │       Dimensions:            (azimuth: 720, range: 1712)
# │       Coordinates:
# │           elevation          (azimuth) float64 6kB ...
# │           time               (azimuth) datetime64[ns] 6kB 2024-05-11T01:10:10.14099...
# │         * range              (range) float32 7kB 2.125e+03 2.375e+03 ... 4.299e+05
# │           longitude          float64 8B ...
# │           latitude           float64 8B ...
# │           altitude           int64 8B ...
# │         * azimuth            (azimuth) float64 6kB 0.2472 0.7471 1.252 ... 359.3 359.7
# │       Data variables:
# │           DBZH               (azimuth, range) float64 10MB ...
# │           ZDR                (azimuth, range) float64 10MB ...
# │           PHIDP              (azimuth, range) float64 10MB ...
# │           RHOHV              (azimuth, range) float64 10MB ...
# │           CCORH              (azimuth, range) float64 10MB ...
# │           sweep_mode         <U20 80B ...
# │           sweep_number       int64 8B ...
# │           prt_mode           <U7 28B ...
# │           follow_mode        <U7 28B ...
# │           sweep_fixed_angle  float64 8B ...
# │       Attributes:
# │           instrument_name:  KBBX
# ├── DataTree('sweep_5')
# │       Dimensions:            (azimuth: 720, range: 1192)
# │       Coordinates:
# │           elevation          (azimuth) float64 6kB ...
# │           time               (azimuth) datetime64[ns] 6kB 2024-05-11T01:10:52.12499...
# │         * range              (range) float32 5kB 2.125e+03 2.375e+03 ... 2.999e+05
# │           longitude          float64 8B ...
# │           latitude           float64 8B ...
# │           altitude           int64 8B ...
# │         * azimuth            (azimuth) float64 6kB 0.2252 0.7278 1.23 ... 359.2 359.7
# │       Data variables:
# │           DBZH               (azimuth, range) float64 7MB ...
# │           VRADH              (azimuth, range) float64 7MB ...
# │           WRADH              (azimuth, range) float64 7MB ...
# │           sweep_mode         <U20 80B ...
# │           sweep_number       int64 8B ...
# │           prt_mode           <U7 28B ...
# │           follow_mode        <U7 28B ...
# │           sweep_fixed_angle  float64 8B ...
# │       Attributes:
# │           instrument_name:  KBBX
# ├── DataTree('sweep_6')
# │       Dimensions:            (azimuth: 360, range: 1540)
# │       Coordinates:
# │           elevation          (azimuth) float64 3kB ...
# │           time               (azimuth) datetime64[ns] 3kB 2024-05-11T01:11:15.50000...
# │         * range              (range) float32 6kB 2.125e+03 2.375e+03 ... 3.869e+05
# │           longitude          float64 8B ...
# │           latitude           float64 8B ...
# │           altitude           int64 8B ...
# │         * azimuth            (azimuth) float64 3kB 0.5438 1.544 2.549 ... 358.5 359.5
# │       Data variables:
# │           DBZH               (azimuth, range) float64 4MB ...
# │           VRADH              (azimuth, range) float64 4MB ...
# │           WRADH              (azimuth, range) float64 4MB ...
# │           ZDR                (azimuth, range) float64 4MB ...
# │           PHIDP              (azimuth, range) float64 4MB ...
# │           RHOHV              (azimuth, range) float64 4MB ...
# │           CCORH              (azimuth, range) float64 4MB ...
# │           sweep_mode         <U20 80B ...
# │           sweep_number       int64 8B ...
# │           prt_mode           <U7 28B ...
# │           follow_mode        <U7 28B ...
# │           sweep_fixed_angle  float64 8B ...
# │       Attributes:
# │           instrument_name:  KBBX
# ├── DataTree('sweep_7')
# │       Dimensions:            (azimuth: 360, range: 1336)
# │       Coordinates:
# │           elevation          (azimuth) float64 3kB ...
# │           time               (azimuth) datetime64[ns] 3kB 2024-05-11T01:11:36.63000...
# │         * range              (range) float32 5kB 2.125e+03 2.375e+03 ... 3.359e+05
# │           longitude          float64 8B ...
# │           latitude           float64 8B ...
# │           altitude           int64 8B ...
# │         * azimuth            (azimuth) float64 3kB 0.5466 1.552 2.541 ... 358.5 359.5
# │       Data variables:
# │           DBZH               (azimuth, range) float64 4MB ...
# │           VRADH              (azimuth, range) float64 4MB ...
# │           WRADH              (azimuth, range) float64 4MB ...
# │           ZDR                (azimuth, range) float64 4MB ...
# │           PHIDP              (azimuth, range) float64 4MB ...
# │           RHOHV              (azimuth, range) float64 4MB ...
# │           CCORH              (azimuth, range) float64 4MB ...
# │           sweep_mode         <U20 80B ...
# │           sweep_number       int64 8B ...
# │           prt_mode           <U7 28B ...
# │           follow_mode        <U7 28B ...
# │           sweep_fixed_angle  float64 8B ...
# │       Attributes:
# │           instrument_name:  KBBX
# ├── DataTree('sweep_8')
# │       Dimensions:            (azimuth: 358, range: 1176)
# │       Coordinates:
# │           elevation          (azimuth) float64 3kB ...
# │           time               (azimuth) datetime64[ns] 3kB 2024-05-11T01:11:56.60800...
# │         * range              (range) float32 5kB 2.125e+03 2.375e+03 ... 2.959e+05
# │           longitude          float64 8B ...
# │           latitude           float64 8B ...
# │           altitude           int64 8B ...
# │         * azimuth            (azimuth) float64 3kB 0.5411 1.544 2.543 ... 358.5 359.5
# │       Data variables:
# │           DBZH               (azimuth, range) float64 3MB ...
# │           VRADH              (azimuth, range) float64 3MB ...
# │           WRADH              (azimuth, range) float64 3MB ...
# │           ZDR                (azimuth, range) float64 3MB ...
# │           PHIDP              (azimuth, range) float64 3MB ...
# │           RHOHV              (azimuth, range) float64 3MB ...
# │           CCORH              (azimuth, range) float64 3MB ...
# │           sweep_mode         <U20 80B ...
# │           sweep_number       int64 8B ...
# │           prt_mode           <U7 28B ...
# │           follow_mode        <U7 28B ...
# │           sweep_fixed_angle  float64 8B ...
# │       Attributes:
# │           instrument_name:  KBBX
# ├── DataTree('sweep_9')
# │       Dimensions:            (azimuth: 360, range: 996)
# │       Coordinates:
# │           elevation          (azimuth) float64 3kB ...
# │           time               (azimuth) datetime64[ns] 3kB 2024-05-11T01:12:16.65200...
# │         * range              (range) float32 4kB 2.125e+03 2.375e+03 ... 2.509e+05
# │           longitude          float64 8B ...
# │           latitude           float64 8B ...
# │           altitude           int64 8B ...
# │         * azimuth            (azimuth) float64 3kB 0.5548 1.544 2.541 ... 358.5 359.6
# │       Data variables:
# │           DBZH               (azimuth, range) float64 3MB ...
# │           VRADH              (azimuth, range) float64 3MB ...
# │           WRADH              (azimuth, range) float64 3MB ...
# │           ZDR                (azimuth, range) float64 3MB ...
# │           PHIDP              (azimuth, range) float64 3MB ...
# │           RHOHV              (azimuth, range) float64 3MB ...
# │           CCORH              (azimuth, range) float64 3MB ...
# │           sweep_mode         <U20 80B ...
# │           sweep_number       int64 8B ...
# │           prt_mode           <U7 28B ...
# │           follow_mode        <U7 28B ...
# │           sweep_fixed_angle  float64 8B ...
# │       Attributes:
# │           instrument_name:  KBBX
# ├── DataTree('sweep_10')
# │       Dimensions:            (azimuth: 360, range: 832)
# │       Coordinates:
# │           elevation          (azimuth) float64 3kB ...
# │           time               (azimuth) datetime64[ns] 3kB 2024-05-11T01:12:35.83900...
# │         * range              (range) float32 3kB 2.125e+03 2.375e+03 ... 2.099e+05
# │           longitude          float64 8B ...
# │           latitude           float64 8B ...
# │           altitude           int64 8B ...
# │         * azimuth            (azimuth) float64 3kB 0.5466 1.549 2.546 ... 358.5 359.5
# │       Data variables:
# │           DBZH               (azimuth, range) float64 2MB ...
# │           VRADH              (azimuth, range) float64 2MB ...
# │           WRADH              (azimuth, range) float64 2MB ...
# │           ZDR                (azimuth, range) float64 2MB ...
# │           PHIDP              (azimuth, range) float64 2MB ...
# │           RHOHV              (azimuth, range) float64 2MB ...
# │           CCORH              (azimuth, range) float64 2MB ...
# │           sweep_mode         <U20 80B ...
# │           sweep_number       int64 8B ...
# │           prt_mode           <U7 28B ...
# │           follow_mode        <U7 28B ...
# │           sweep_fixed_angle  float64 8B ...
# │       Attributes:
# │           instrument_name:  KBBX
# └── DataTree('sweep_11')
#         Dimensions:            (azimuth: 360, range: 688)
#         Coordinates:
#             elevation          (azimuth) float64 3kB ...
#             time               (azimuth) datetime64[ns] 3kB 2024-05-11T01:12:55.02899...
#           * range              (range) float32 3kB 2.125e+03 2.375e+03 ... 1.739e+05
#             longitude          float64 8B ...
#             latitude           float64 8B ...
#             altitude           int64 8B ...
#           * azimuth            (azimuth) float64 3kB 0.5576 1.549 2.546 ... 358.6 359.5
#         Data variables:
#             DBZH               (azimuth, range) float64 2MB ...
#             VRADH              (azimuth, range) float64 2MB ...
#             WRADH              (azimuth, range) float64 2MB ...
#             ZDR                (azimuth, range) float64 2MB ...
#             PHIDP              (azimuth, range) float64 2MB ...
#             RHOHV              (azimuth, range) float64 2MB ...
#             CCORH              (azimuth, range) float64 2MB ...
#             sweep_mode         <U20 80B ...
#             sweep_number       int64 8B ...
#             prt_mode           <U7 28B ...
#             follow_mode        <U7 28B ...
#             sweep_fixed_angle  float64 8B ...
#         Attributes:
#             instrument_name:  KBBX

# %%
def rms(signal):
    return np.sqrt(np.mean(signal**2))

# %%
for group in list(datatree.groups):
    print(group)

# data tree is a tuple, an ordered list of elements, the first element is the root '/'

display(type(datatree.groups))
root = datatree.groups
display(root[0])
display(root[2])
display(len(root))
sweep = root[2]
display(type(sweep))
sweeps = datatree.children
display(type(sweeps))

print("is hollow? ", datatree.is_hollow)
# [node.data_vars for node in datatree.leaves]
# node.children gets the name of the node as a string
# node.subtree generates an iterable over the nodes of the tree in depth-first order
for node in datatree.subtree:
    print(node.name, " path: ", node.path)

# get field variables from a datatree ...
sweep0 = datatree["/sweep_0"]
display(type(sweep0))
#display(sweep0.data_vars)
print("dims: ", sweep0.dims)
print("data_vars: ", sweep0.data_vars)
sweep0_data_vars = sweep0.data_vars
fieldnames = []
for k, v in sweep0_data_vars.items():
    print(k, len(v.dims))
    if len(v.dims) >= 2:
        fieldnames.append(k)


display("fields names: ", fieldnames)
# Out:
# /
# /sweep_0
# /sweep_1
# /sweep_2
# /sweep_3
# /sweep_4
# /sweep_5
# /sweep_6
# /sweep_7
# /sweep_8
# /sweep_9
# /sweep_10
# /sweep_11
# tuple
# '/'
# '/sweep_1'
# 13
# str
# xarray.core.utils.Frozen
# is hollow?  False
# root  path:  /
# sweep_0  path:  /sweep_0
# sweep_1  path:  /sweep_1
# sweep_2  path:  /sweep_2
# sweep_3  path:  /sweep_3
# sweep_4  path:  /sweep_4
# sweep_5  path:  /sweep_5
# sweep_6  path:  /sweep_6
# sweep_7  path:  /sweep_7
# sweep_8  path:  /sweep_8
# sweep_9  path:  /sweep_9
# sweep_10  path:  /sweep_10
# sweep_11  path:  /sweep_11
# datatree.datatree.DataTree
# dims:  Frozen({'azimuth': 720, 'range': 1832})
# data_vars:  Data variables:
#     DBZH               (azimuth, range) float64 11MB ...
#     ZDR                (azimuth, range) float64 11MB ...
#     PHIDP              (azimuth, range) float64 11MB ...
#     RHOHV              (azimuth, range) float64 11MB ...
#     CCORH              (azimuth, range) float64 11MB ...
#     sweep_mode         <U20 80B ...
#     sweep_number       int64 8B ...
#     prt_mode           <U7 28B ...
#     follow_mode        <U7 28B ...
#     sweep_fixed_angle  float64 8B ...
# DBZH 2
# ZDR 2
# PHIDP 2
# RHOHV 2
# CCORH 2
# sweep_mode 0
# sweep_number 0
# prt_mode 0
# follow_mode 0
# sweep_fixed_angle 0
# 'fields names: '
# ['DBZH', 'ZDR', 'PHIDP', 'RHOHV', 'CCORH']

# %%
# data tree is a tuple, an ordered list of elements, the first element is the root '/'

# node.children gets the name of the node as a string
# node.subtree generates an iterable over the nodes of the tree in depth-first order

def get_field_names(datatree):
# get field variables from a datatree ...
    sweep0 = datatree["/sweep_0"] # TODO make this more general and robust
    #print("dims: ", sweep0.dims)
    #print("data_vars: ", sweep0.data_vars)
    sweep0_data_vars = sweep0.data_vars
    fieldnames = []
    for k, v in sweep0_data_vars.items():
        #print(k, len(v.dims))
        if len(v.dims) >= 2:
            fieldnames.append(k)
    return fieldnames

display("fields names: ", get_field_names(datatree))
# Out:
# 'fields names: '
# ['DBZH', 'ZDR', 'PHIDP', 'RHOHV', 'CCORH']

# %%
#list(datatree.groups)
len(datatree.groups)
# Out:
# 13

# %%
def get_sweeps(datatree):
# get the number of sweeps from a datatree ...
    return len(datatree.groups) - 1
    
print("number of sweeps: ", get_sweeps(datatree))
# Out:
# number of sweeps:  12

# %%
#list(ds.data_vars)
# get field variables from a dataset
#def get_field_names(dataset):
#    field_names = []
#    ds = dataset
#    for v in list(ds.data_vars):
#        the_var = ds.data_vars[v]
#        print(type(the_var))
#        dim = len(ds.data_vars[v].shape)
#        print(v, dim, ds.data_vars[v].shape) # , len(the_var))
#        if dim == 2:
#            #print(v)
#            field_names.append(v)

#field_names = ['SDP', 'SQI2', 'DBZ2', 'FDP', 'WIDTH2', 'KDP', 'KDP2', 'DBT2', 'RHOHV2', 'SNR16', 'CC', 'ZDR2', 'HID', 'CV', 'PHIDP2', 'UNKNOWN_82', 'VEL2', 'DZQC']
#print(field_names)
#field_names_widget = pn.widgets.Select(name="field", options=list(field_names))
#pn.Column(field_names_widget)

# %%
field_names_widget = pn.widgets.Select(name="field", options=get_field_names(datatree))

# %%
#def get_data_set(variable):
#    ds = xr.open_dataset(variable, engine='cfradial1')
#    return ds
# do NOT use
def get_fields_do_not_use(variable=[]):  # ="*.nc"):
    print(variable)
    field_names = []
    if (variable):
        ds = xr.open_dataset(variable) # , engine='cfradial1')  # "/home/jovyan/notebooks/data-access/ARPA_Lombardia.20240522.151546_dealiased.nc") # , group="sweep_0") # , engine="nexradlevel2")
        for v in list(ds.data_vars):
            # print(v)
            dim = len(ds.data_vars[v].shape)
            if dim == 2:
                print(v)
                field_names.append(v)
    field_names_widget = pn.widgets.Select(name="field", options=list(field_names))
    return field_names_widget

# %%
#test_names = get_fields("/home/jovyan/notebooks/data-access/ARPA_Lombardia.20240522.151546_dealiased.nc")
#test_names

# %%
#bound_plot = pn.bind(
#    get_data_set, variable=file_selector_widget
#)

#bound_plot2 = pn.bind(
#    get_fields, ds=get_data_set
#)
#wd = get_fields("/Users/brenda/data/PRECIP/SEA20220702_001310_ppi.nc")
#wd

# %%
#
#pst = get_fields(dst)
#pst

def show_selected_field(x):
    return f'selected field is {x}'
    
bound_get_fields = pn.bind(get_fields, variable=file_selector_widget)
pn.Column(card, bound_get_fields)

#pn.Column(
#    #"Which calculation would you like to perform?",
#    card,
#    ,
#    get_fields
#).servable()
# Out:
# ['/Users/brenda/data/cfrad.20161006_190650.891_to_20161006_191339.679_KAMX_SUR.nc']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 5
#       1 #
#       2 #pst = get_fields(dst)
#       3 #pst
#       4 bound_get_fields = pn.bind(get_fields, variable=file_selector_widget)
# ----> 5 pn.Column(card, bound_get_fields)
#       7 #pn.Column(
#       8 #    #"Which calculation would you like to perform?",
#       9 #    card,
#      10 #    ,
#      11 #    get_fields
#      12 #).servable()
#
# File ~/miniforge3/envs/bokeh_heatmap_env/lib/python3.12/site-packages/panel/layout/base.py:820, in ListPanel.__init__(self, *objects, **params)
#     816     if 'objects' in params:
#     817         raise ValueError("A %s's objects should be supplied either "
#     818                          "as positional arguments or as a keyword, "
#     819                          "not both." % type(self).__name__)
# --> 820     params['objects'] = [panel(pane) for pane in objects]
#     821 elif 'objects' in params:
#     822     objects = params['objects']
#
# File ~/miniforge3/envs/bokeh_heatmap_env/lib/python3.12/site-packages/panel/pane/base.py:86, in panel(obj, **kwargs)
#      84 if kwargs.get('name', False) is None:
#      85     kwargs.pop('name')
# ---> 86 pane = PaneBase.get_pane_type(obj, **kwargs)(obj, **kwargs)
#      87 if len(pane.layout) == 1 and pane._unpack:
#      88     return pane.layout[0]
#
# File ~/miniforge3/envs/bokeh_heatmap_env/lib/python3.12/site-packages/panel/param.py:814, in ParamRef.__init__(self, object, **params)
#     812 self._validate_object()
#     813 if not self.defer_load:
# --> 814     self._replace_pane()
#
# File ~/miniforge3/envs/bokeh_heatmap_env/lib/python3.12/site-packages/panel/param.py:882, in ParamRef._replace_pane(self, force, *args)
#     880 else:
#     881     try:
# --> 882         new_object = self.eval(self.object)
#     883         if new_object is Skip and new_object is Undefined:
#     884             self._inner_layout.loading = False
#
# File ~/miniforge3/envs/bokeh_heatmap_env/lib/python3.12/site-packages/panel/param.py:1097, in ParamFunction.eval(self, ref)
#    1095 @classmethod
#    1096 def eval(self, ref):
# -> 1097     return eval_function_with_deps(ref)
#
# File ~/miniforge3/envs/bokeh_heatmap_env/lib/python3.12/site-packages/param/parameterized.py:165, in eval_function_with_deps(function)
#     163         args = (getattr(dep.owner, dep.name) for dep in arg_deps)
#     164         kwargs = {n: getattr(dep.owner, dep.name) for n, dep in kw_deps.items()}
# --> 165 return function(*args, **kwargs)
#
# File ~/miniforge3/envs/bokeh_heatmap_env/lib/python3.12/site-packages/param/depends.py:53, in depends.<locals>._depends(*args, **kw)
#      51 @wraps(func)
#      52 def _depends(*args, **kw):
# ---> 53     return func(*args, **kw)
#
# File ~/miniforge3/envs/bokeh_heatmap_env/lib/python3.12/site-packages/param/reactive.py:594, in bind.<locals>.wrapped(*wargs, **wkwargs)
#     591 @depends(**dependencies, watch=watch)
#     592 def wrapped(*wargs, **wkwargs):
#     593     combined_args, combined_kwargs = combine_arguments(wargs, wkwargs)
# --> 594     return eval_fn()(*combined_args, **combined_kwargs)
#
# Cell In[6], line 9, in get_fields(variable)
#       7 field_names = []
#       8 if (variable):
# ----> 9     ds = xr.open_dataset(variable) # , engine='cfradial1')  # "/home/jovyan/notebooks/data-access/ARPA_Lombardia.20240522.151546_dealiased.nc") # , group="sweep_0") # , engine="nexradlevel2")
#      10     for v in list(ds.data_vars):
#      11         # print(v)
#      12         dim = len(ds.data_vars[v].shape)
#
# File ~/miniforge3/envs/bokeh_heatmap_env/lib/python3.12/site-packages/xarray/backends/api.py:552, in open_dataset(filename_or_obj, engine, chunks, cache, decode_cf, mask_and_scale, decode_times, decode_timedelta, use_cftime, concat_characters, decode_coords, drop_variables, inline_array, chunked_array_type, from_array_kwargs, backend_kwargs, **kwargs)
#     549     kwargs.update(backend_kwargs)
#     551 if engine is None:
# --> 552     engine = plugins.guess_engine(filename_or_obj)
#     554 if from_array_kwargs is None:
#     555     from_array_kwargs = {}
#
# File ~/miniforge3/envs/bokeh_heatmap_env/lib/python3.12/site-packages/xarray/backends/plugins.py:197, in guess_engine(store_spec)
#     189 else:
#     190     error_msg = (
#     191         "found the following matches with the input file in xarray's IO "
#     192         f"backends: {compatible_engines}. But their dependencies may not be installed, see:\n"
#     193         "https://docs.xarray.dev/en/stable/user-guide/io.html \n"
#     194         "https://docs.xarray.dev/en/stable/getting-started-guide/installing.html"
#     195     )
# --> 197 raise ValueError(error_msg)
#
# ValueError: did not find a match in any of xarray's currently installed IO backends ['netcdf4', 'h5netcdf', 'scipy', 'cfradial1', 'furuno', 'gamic', 'iris', 'nexradlevel2', 'odim', 'rainbow']. Consider explicitly selecting one of the installed engines via the ``engine`` parameter, or installing additional IO dependencies, see:
# https://docs.xarray.dev/en/stable/getting-started-guide/installing.html
# https://docs.xarray.dev/en/stable/user-guide/io.html

# %%
# make this into a stand alone app
pn.template.MaterialTemplate(
    site="Panel",
    title="Getting Started App",
    #sidebar=[field_names_widget],
    #main=[card]
    # main=[field_names_widget]
    main=[bound_slider]
#    main=[card, bound_get_fields]
).servable(); # The ; is needed in the notebook to not display the template. Its not needed in a script

# %%
#help(pn.servable)
#help(pn.viewable)

#def transform_data(variable, window, sigma):
#    """Calculates the rolling average and identifies outliers"""
#    avg = data[variable].rolling(window=window).mean()
#    residual = data[variable] - avg
#    std = residual.rolling(window=window).std()
#    outliers = np.abs(residual) > std * sigma
#    return avg, avg[outliers]


#def get_plot(variable="Temperature", window=30, sigma=10):
#    """Plots the rolling average and the outliers"""
#    #avg, highlight = transform_data(variable, window, sigma)
#    avg = [1,3,4,5,6]
#    return avg.hvplot(
#        height=300, legend=False, color=PRIMARY_COLOR
#    ) #  * highlight.hvplot.scatter(color=SECONDARY_COLOR, padding=0.1, legend=False)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 help(pn.servable)
#       2 #help(pn.viewable)
#       3
#       4 #def transform_data(variable, window, sigma):
#    (...)
#      18 #        height=300, legend=False, color=PRIMARY_COLOR
#      19 #    ) #  * highlight.hvplot.scatter(color=SECONDARY_COLOR, padding=0.1, legend=False)
#
# AttributeError: module 'panel' has no attribute 'servable'

# %%
#get_plot(variable='Temperature', window=20, sigma=10)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 get_plot(variable='Temperature', window=20, sigma=10)
#
# Cell In[22], line 17, in get_plot(variable, window, sigma)
#      15 #avg, highlight = transform_data(variable, window, sigma)
#      16 avg = [1,3,4,5,6]
# ---> 17 return avg.hvplot(
#      18     height=300, legend=False, color=PRIMARY_COLOR
#      19 )
#
# AttributeError: 'list' object has no attribute 'hvplot'

# %%
# HERE ...
#variable_widget = pn.widgets.Select(name="variable", value="Temperature", options=list(data.columns))
#window_widget = pn.widgets.IntSlider(name="window", value=30, start=1, end=60)
#sigma_widget = pn.widgets.IntSlider(name="sigma", value=10, start=0, end=20)

# %%
#bound_plot = pn.bind(
#    get_plot, variable=variable_widget, window=window_widget, sigma=sigma_widget
#)

# %%
#widgets = pn.Column(variable_widget, window_widget, sigma_widget, sizing_mode="fixed", width=300)
#pn.Column(widgets, bound_plot)

# %%
#pn.template.MaterialTemplate(
#    site="Panel",
#    title="Getting Started App",
#    sidebar=[variable_widget, window_widget, sigma_widget],
#    main=[bound_plot],
#).servable(); # The ; is needed in the notebook to not display the template. Its not needed in a script

# %%
# If you prefer developing in a Python Script using an editor, you can copy the code into a file app.py and serve it.

# panel serve app.py --autoreload
